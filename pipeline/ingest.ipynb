# %% [markdown]
# **Step 1 of 3 — Data Acquisition & Cleaning**
#
# Downloads the ULB Credit Card Fraud Detection dataset from Kaggle, validates the expected schema, cleans the data, and outputs cleaned.csv.
#
# How to run: ingest.ipynb → enrich.ipynb → load_mongo.ipynb

# %%
import os
import logging
import pandas as pd

# %%
#Configuration
#Expected columns in the raw ULB dataset
REQUIRED_COLUMNS = (
    ["Time"] +
    [f"V{i}" for i in range(1, 29)] +
    ["Amount", "Class"]
)
RAW_PATH = "creditcard.csv"
OUTPUT_PATH = "cleaned.csv"

# %%
#Download Dataset
# Load dataset from Colab /content folder
if not os.path.exists(RAW_PATH):
    raise FileNotFoundError(f"Upload creditcard.csv to the Colab Files panel first.")

# %%
# Load raw data
df_raw = pd.read_csv(RAW_PATH)
df_raw.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Load raw data
df_raw = pd.read_csv(RAW_PATH)
logging.info(f"Loaded {len(df_raw)} rows, {len(df_raw.columns)} columns.")
df_raw.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Clean data — drop duplicates, nulls, invalid Class and Amount values
df_clean = df_raw.drop_duplicates().dropna()
df_clean = df_clean[df_clean["Class"].isin([0, 1])]
df_clean = df_clean[df_clean["Amount"] >= 0]
df_clean["Class"] = df_clean["Class"].astype(int)

logging.info(f"Cleaned data: {len(df_clean)} rows | Fraud rate: {df_clean['Class'].mean():.4%}")
df_clean.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#Summary Statitics
print(df_clean["Class"].value_counts())
print(df_clean["Amount"].describe().round(2))
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64
# count    283726.00
# mean         88.47
# std         250.40
# min           0.00
# 25%           5.60
# 50%          22.00
# 75%          77.51
# max       25691.16
# Name: Amount, dtype: float64

# %%
#saving the clean data
df_clean.to_csv(OUTPUT_PATH, index=False)
logging.info(f"Cleaned data saved to {OUTPUT_PATH}")
